# %%
# Install Kaggle
# !pip install kaggle

# Upload kaggle.json file (from Kaggle account)
from google.colab import files
files.upload()
import pandas as pd
df = pd.read_csv("Reviews.csv")

# Take smaller sample for speed
df = df.head(1000)
df.head()
# Out:
# ...
#      <input type="file" id="files-26415c0c-7bac-41bf-ac9d-0585bf9882e3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-26415c0c-7bac-41bf-ac9d-0585bf9882e3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
# The previous dataset 'algozee/global-movie-trends-2026' was not found (404 error).
# Please ensure the dataset handle is correct and publicly accessible.
# As an example, we will use a common public dataset: 'datasets/titanic'.
# You can find the correct handle by navigating to the dataset on Kaggle and copying the 'Owner/DatasetName'.
# You might also need to list files within the dataset to find the correct file_path.
# For 'datasets/titanic', a common file is 'train.csv'.
file_path = "train.csv"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "datasets/titanic", # Replaced with a valid public dataset handle for demonstration
  file_path,
  # Provide any additional arguments like
  # sql_query or pandas_kwargs. See the
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# /tmp/ipykernel_8206/879234767.py:16: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/kagglehub/exceptions.py in handle_call(fn, resource_handle)
#      66     try:
# ---> 67         return fn()
#      68     except requests.HTTPError as e:
#
# /usr/local/lib/python3.12/dist-packages/kagglehub/http_resolver.py in <lambda>()
#     363         r.dataset_slug = h.dataset
# --> 364         dataset = handle_call(lambda: api_client.datasets.dataset_api_client.get_dataset(r))
#     365         return dataset.current_version_number
#
# /usr/local/lib/python3.12/dist-packages/kagglesdk/datasets/services/dataset_api_service.py in get_dataset(self, request)
#      32
# ...
